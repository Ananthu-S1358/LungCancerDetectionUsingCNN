# %% [markdown]
# # Chest and Lung Cancer Prediction Convolutional Neural Network

# %% [markdown]
# ### Importing the libraries

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# ## Part 1 - Data Preprocessing

# %% [markdown]
# ### Preprocessing the Training set

# %%
train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = True)
training_set = train_datagen.flow_from_directory('dataset/training_set',
                                                 target_size = (64, 64),
                                                 batch_size = 32,
                                                 class_mode = 'binary')
# Out:
# Found 343 images belonging to 2 classes.

# %% [markdown]
# ### Preprocessing the Test set

# %%
test_datagen = ImageDataGenerator(rescale = 1./255)
test_set = test_datagen.flow_from_directory('dataset/test_set',
                                            target_size = (64, 64),
                                            batch_size = 32,
                                            class_mode = 'binary')
# Out:
# Found 112 images belonging to 2 classes.

# %% [markdown]
# ## Part 2 - Building the CNN

# %% [markdown]
# ### Initialising the CNN

# %%
cnn = tf.keras.models.Sequential()

# %% [markdown]
# ### Step 1 - Convolution

# %%
cnn.add(tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation='relu', input_shape=[64, 64,3]))
# Out:
# C:\Users\ANANTHU\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# ### Step 2 - Pooling

# %%
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))

# %% [markdown]
# ### Adding a second convolutional layer

# %%
cnn.add(tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation='relu'))
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))

# %% [markdown]
# ### Step 3 - Flattening

# %%
cnn.add(tf.keras.layers.Flatten())

# %% [markdown]
# ### Step 4 - Full Connection

# %%
cnn.add(tf.keras.layers.Dense(units=128, activation='relu'))

# %% [markdown]
# ### Step 5 - Output Layer

# %%
cnn.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# %% [markdown]
# ## Part 3 - Training the CNN

# %% [markdown]
# ### Compiling the CNN

# %%
cnn.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
from PIL import Image

# %% [markdown]
# ### Training the CNN on the Training set and evaluating it on the Test set

# %%
cnn.fit(x = training_set, validation_data = test_set, epochs = 30)
# Out:
# Epoch 1/30
# C:\Users\ANANTHU\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 104ms/step - accuracy: 0.4881 - loss: 0.7071 - val_accuracy: 0.7946 - val_loss: 0.5535
# Epoch 2/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - accuracy: 0.8180 - loss: 0.5554 - val_accuracy: 0.8393 - val_loss: 0.3692
# Epoch 3/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.7733 - loss: 0.4545 - val_accuracy: 0.9464 - val_loss: 0.2009
# Epoch 4/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - accuracy: 0.8610 - loss: 0.2961 - val_accuracy: 0.9911 - val_loss: 0.0689
# Epoch 5/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - accuracy: 0.8861 - loss: 0.2765 - val_accuracy: 0.9821 - val_loss: 0.1006
# Epoch 6/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - accuracy: 0.9154 - loss: 0.2444 - val_accuracy: 1.0000 - val_loss: 0.0535
# Epoch 7/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.9491 - loss: 0.1730 - val_accuracy: 0.9732 - val_loss: 0.0596
# Epoch 8/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - accuracy: 0.9279 - loss: 0.1466 - val_accuracy: 0.9732 - val_loss: 0.0520
# Epoch 9/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - accuracy: 0.9654 - loss: 0.1018 - val_accuracy: 0.9732 - val_loss: 0.0440
# Epoch 10/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - accuracy: 0.9468 - loss: 0.1242 - val_accuracy: 0.9732 - val_loss: 0.0400
# Epoch 11/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - accuracy: 0.9516 - loss: 0.1426 - val_accuracy: 0.9911 - val_loss: 0.0194
# Epoch 12/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - accuracy: 0.9686 - loss: 0.0890 - val_accuracy: 0.9911 - val_loss: 0.0367
# Epoch 13/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - accuracy: 0.9851 - loss: 0.0702 - val_accuracy: 0.9911 - val_loss: 0.0249
# Epoch 14/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - accuracy: 0.9592 - loss: 0.1011 - val_accuracy: 0.9911 - val_loss: 0.0264
# Epoch 15/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - accuracy: 0.9793 - loss: 0.0575 - val_accuracy: 0.9911 - val_loss: 0.0304
# Epoch 16/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - accuracy: 0.9732 - loss: 0.0623 - val_accuracy: 0.9821 - val_loss: 0.0686
# Epoch 17/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - accuracy: 0.9884 - loss: 0.0525 - val_accuracy: 0.9911 - val_loss: 0.0425
# Epoch 18/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - accuracy: 0.9965 - loss: 0.0248 - val_accuracy: 0.9911 - val_loss: 0.0269
# Epoch 19/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - accuracy: 0.9914 - loss: 0.0425 - val_accuracy: 1.0000 - val_loss: 0.0224
# Epoch 20/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - accuracy: 0.9710 - loss: 0.0757 - val_accuracy: 0.9554 - val_loss: 0.1263
# Epoch 21/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step - accuracy: 0.9827 - loss: 0.0688 - val_accuracy: 0.9821 - val_loss: 0.0762
# Epoch 22/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step - accuracy: 0.9934 - loss: 0.0366 - val_accuracy: 0.9732 - val_loss: 0.1707
# Epoch 23/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - accuracy: 0.9907 - loss: 0.0279 - val_accuracy: 0.9821 - val_loss: 0.0560
# Epoch 24/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step - accuracy: 0.9768 - loss: 0.0442 - val_accuracy: 0.9643 - val_loss: 0.1741
# Epoch 25/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - accuracy: 0.9943 - loss: 0.0213 - val_accuracy: 0.9821 - val_loss: 0.0713
# Epoch 26/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - accuracy: 0.9864 - loss: 0.0215 - val_accuracy: 0.9821 - val_loss: 0.0537
# Epoch 27/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - accuracy: 1.0000 - loss: 0.0125 - val_accuracy: 0.9821 - val_loss: 0.0839
# Epoch 28/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - accuracy: 0.9965 - loss: 0.0212 - val_accuracy: 0.9911 - val_loss: 0.0275
# Epoch 29/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - accuracy: 0.9807 - loss: 0.0438 - val_accuracy: 0.9643 - val_loss: 0.1192
# Epoch 30/30
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.9923 - loss: 0.0276 - val_accuracy: 0.9732 - val_loss: 0.1456

# %% [markdown]
# ## Part 4 - Making a single prediction

# %%
import numpy as np
from keras.preprocessing import image
test_image = image.load_img('dataset/single_prediction/cancer (4).png', target_size = (64, 64))
test_image = image.img_to_array(test_image)
test_image = np.expand_dims(test_image, axis = 0)
result = cnn.predict(test_image)
training_set.class_indices
if result[0][0] == 1:
  prediction = 'normal'
else:
  prediction = 'cancer'
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step

# %%
print(prediction)
# Out:
# cancer

# %%
# Evaluate the model on the test set
test_loss, test_accuracy = cnn.evaluate(test_set)

# Print the test accuracy
print(f"Test Accuracy: {test_accuracy * 100:.2f}%")
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.9705 - loss: 0.1856
# Test Accuracy: 97.32%

# %%
model_json = cnn.to_json()
with open("lungCancer.json",'w') as json_file:
    json_file.write(model_json)
cnn.save("lungCancer.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
from keras.models import model_from_json

# %%
json_file = open("lungCancer.json", "r")
model_json = json_file.read()
json_file.close()
model1 = model_from_json(model_json)
model1.load_weights("lungCancer.h5")

# %%
import numpy as np
from keras.preprocessing import image
import matplotlib.pyplot as plt

def predict_and_show_image(model, img_path, target_size=(64, 64)):
    # Load the image
    test_image = image.load_img(img_path, target_size=target_size)

    # Convert the image to an array and expand dimensions to match the model input shape
    test_image_array = image.img_to_array(test_image)
    test_image_array = np.expand_dims(test_image_array, axis=0)

    # Predict the class of the image
    result = model1.predict(test_image_array)
    
    # Map the result to a class label
    prediction = 'normal' if result[0][0] == 1 else 'cancer'

    # Print the prediction
    print(f'Prediction: {prediction}')

    # Display the image using matplotlib
    plt.imshow(image.load_img(img_path))
    plt.title(f'Prediction: {prediction}')
    plt.axis('off')  # Hide the axes
    plt.show()

# %%
# Example usage:
predict_and_show_image(model1, 'dataset/single_prediction/cancer (8).png')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Prediction: cancer
